# %%
import sqlite3

# %%
conn = sqlite3.connect("fintrackai.db")

# %%
cur = conn.cursor()

# %%
cur.execute('''
            create table user(
            user_id int primary key,
            user_name varchar(40),
            gender varchar(20),
            email varchar(100),
            password_hash text,
            created_at datetime
            )
            ''')

# %%
conn.commit()

# %%
cur.execute("INSERT INTO EXPENSEPROFILE VALUES()")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 cur.execute("INSERT INTO EXPENSEPROFILE VALUES()")
#
# OperationalError: near ")": syntax error

# %%
conn.commit()

# %%
conn.execute("drop table verification")
conn.commit()

# %%
cur.execute('''
        CREATE TABLE VERIFICATION(
            OTP_ID INT PRIMARY KEY,
            USER_ID INT,
            EMAIL_OTP INT,
            OTP_EXP DATETIME,
            OTP_CREATION DATETIME,
            OTP_STATUS VARCHAR(30) CHECK(OTP_STATUS IN("VERIFIED","NOT VERIFIED")),
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)

        )
        ''')

# %%
cur.execute('''
        CREATE TABLE INCOMEPROFILE(
            PROFILE_ID INT PRIMARY KEY,
            USER_ID INT,
            INCOME_TYPE VARCHAR(40) CHECK(INCOME_TYPE IN("SALARIED","PROFESSIONAL","BUSINESS","OTHERS")),
            MONTHLY_INCOME FLOAT,
            ADDITIONAL_INCOME_TYPE VARCHAR(50) CHECK(ADDITIONAL_INCOME_TYPE IN("STOCK","INVESTEMENTS","BUSINESS","OTHERS")),
            ADDITIONAL_MONTHLY_INCOME FLOAT,
            DEPENDANTS INT CHECK(DEPENDANTS<20),
            CREATED_AT DATETIME,
            UPDATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
        )
        ''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 cur.execute('''
#       2         CREATE TABLE INCOMEPROFILE(
#       3             PROFILE_ID INT PRIMARY KEY,
#       4             USER_ID INT,
#       5             INCOME_TYPE VARCHAR(40) CHECK(INCOME_TYPE IN("SALARIED","PROFESSIONAL","BUSINESS","OTHERS")),
#       6             MONTHLY_INCOME FLOAT,
#       7             ADDITIONAL_INCOME_TYPE VARCHAR(50) CHECK(ADDITIONAL_INCOME_TYPE IN("STOCK","INVESTEMENTS","BUSINESS","OTHERS")),
#       8             ADDITIONAL_MONTHLY_INCOME FLOAT,
#       9             DEPENDANTS INT CHECK(DEPENDANTS<20),
#      10             CREATED_AT DATETIME,
#      11             UPDATED_AT DATETIME,
#      12             FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
#      13         )
#      14         ''')
#
# OperationalError: table INCOMEPROFILE already exists

# %%
cur.execute('''
    INSERT INTO INCOMEPROFILE VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
''', (
    2,
    6,
    "BUSINESS",
    80000.0,
    "OTHERS",
    10000.0,
    3,
    "2026-04-06 11:00:00",
    "2026-04-06 11:00:00"
))

# %%
conn.commit()

# %%
cur.execute('''
        CREATE TABLE EXPENSEPROFILE(
            EXPENSE_ID INT PRIMARY KEY,
            USER_ID INT,
            GROCERIES FLOAT,
            TRAVEL FLOAT,
            MEDFIT FLOAT,
            LEP FLOAT,
            MONTHLY_RENT FLOAT,
            M_BILLS FLOAT,
            FASHION FLOAT,
            ENTERTAINMENT FLOAT,
            EDUCATION FLOAT,
            EMSAVING FLOAT,
            MISCELLANEOUS FLOAT,
            CREATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
        )
        ''')

# %%
conn.commit()

# %%
cur.execute('''
        CREATE TABLE GOALS(
            GOALID INT PRIMARY KEY,
            USER_ID INT,
            GOAL_NAME VARCHAR(100),
            START_DATE DATETIME,
            END_DATE DATETIME,
            GOAL_AMOUNT FLOAT,
            MONTHLY_SAVING_T FLOAT,
            GOAL_STATUS VARCHAR(50) CHECK(GOAL_STATUS IN("ACTIVE","PAUSED","ACHIEVED","EXPIRED","INACTIVE")),
            CREATED_AT DATETIME,
            UPDATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID))
            

     
        ''')

# %%
conn.commit()

# %%
cur.execute('''
        CREATE TABLE GOAL_HISTORY(
        HISTORY_ID INT PRIMARY KEY,
        GOALID INT,
        CREATED_AT DATETIME,
        SAVE_MONTH FLOAT,
        FOREIGN KEY(GOALID) REFERENCES GOALS(GOALID))
     
        ''')

# %%
import datetime
cur.execute(f'''
    INSERT INTO USER VALUES(2,"paul","MALE","PAUL@GMAIL.COM","JHVCUYWFWEFSADT7F875JHV3296","{datetime.datetime.now()}")
        ''')

# %%
conn.commit()

# %%
cur.execute("SELECT * FROM USER")
x = cur.fetchall()
x
# Out:
# [(2,
#   'paul',
#   'MALE',
#   'PAUL@GMAIL.COM',
#   'JHVCUYWFWEFSADT7F875JHV3296',
#   '2026-03-30 01:20:47.196888'),
#  (3,
#   'jacob',
#   'Male',
#   'jacob@gmail.com',
#   'scrypt:32768:8:1$kClqICHE704qLF3Y$c2b92e0ece13e421abb68088a4eb57502d2dd87f88a8a3927a5c204d0948bedfcd5da666a0f8dcfaffe9577ca4a994c838e297196832d7f4c21e88baa8b42f30',
#   '2026-03-30 21:34:09.719708'),
#  (4,
#   'janvi',
#   'Female',
#   'illajahnavi14@gmail.com',
#   'scrypt:32768:8:1$iTjjdNBLexnjH6K1$87cf3d2b7304ca7c38575bbbd372e164e7193a48349f34862665e007bf96c6748ebe095a42808e33de3a20134e1f8acb27ed9090de4dd08f3f50e950b64518cd',
#   '2026-03-31 11:10:08.422759'),
#  (5,
#   'janu',
#   'Female',
#   'januilla1410@gamil.com',
#   'scrypt:32768:8:1$ru9o7Z1KxCi1jchP$d51572b5e10afc4667647f5e64f62844fbdf828924ea7cce91bcd49fed1a78e70f14795f5b2a51d7afbbb24dc35c72adee42efe3d9ac7f4e2214fc28a6dfcaa8',
#   '2026-03-31 12:08:56.736498')]

# %%
cur.execute("select max(otp_id) from verification")
x=cur.fetchall()
x[0][0]+1
# Out:
# 2

# %%
cur.execute("INSERT INTO VERIFICATION VALUES(1,2,6057,1038464.56,'2025-03-04 15:20:30','VERIFIED')")
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cur.execute("INSERT INTO VERIFICATION VALUES(1,2,6057,1038464.56,'2025-03-04 15:20:30','VERIFIED')")
#       2 conn.commit()
#
# IntegrityError: UNIQUE constraint failed: VERIFICATION.OTP_ID

# %%
cur.execute("INSERT INTO VERIFICATION VALUES(2,3,6058,1038474.57,'2025-03-03 16:21:30','VERIFIED')")
conn.commit()

# %%
cur.execute("select email, password_hash from user")
cur.fetchall()
# Out:
# [('PAUL@GMAIL.COM', 'JHVCUYWFWEFSADT7F875JHV3296'),
#  ('jacob@gmail.com',
#   'scrypt:32768:8:1$kClqICHE704qLF3Y$c2b92e0ece13e421abb68088a4eb57502d2dd87f88a8a3927a5c204d0948bedfcd5da666a0f8dcfaffe9577ca4a994c838e297196832d7f4c21e88baa8b42f30'),
#  ('illajahnavi14@gmail.com',
#   'scrypt:32768:8:1$iTjjdNBLexnjH6K1$87cf3d2b7304ca7c38575bbbd372e164e7193a48349f34862665e007bf96c6748ebe095a42808e33de3a20134e1f8acb27ed9090de4dd08f3f50e950b64518cd')]

# %%
cur.execute("select * from user")
cur.fetchall()
# Out:
# [(2,
#   'paul',
#   'MALE',
#   'PAUL@GMAIL.COM',
#   'JHVCUYWFWEFSADT7F875JHV3296',
#   '2026-03-30 01:20:47.196888'),
#  (3,
#   'jacob',
#   'Male',
#   'jacob@gmail.com',
#   'scrypt:32768:8:1$kClqICHE704qLF3Y$c2b92e0ece13e421abb68088a4eb57502d2dd87f88a8a3927a5c204d0948bedfcd5da666a0f8dcfaffe9577ca4a994c838e297196832d7f4c21e88baa8b42f30',
#   '2026-03-30 21:34:09.719708'),
#  (4,
#   'janvi',
#   'Female',
#   'illajahnavi14@gmail.com',
#   'scrypt:32768:8:1$iTjjdNBLexnjH6K1$87cf3d2b7304ca7c38575bbbd372e164e7193a48349f34862665e007bf96c6748ebe095a42808e33de3a20134e1f8acb27ed9090de4dd08f3f50e950b64518cd',
#   '2026-03-31 11:10:08.422759'),
#  (5,
#   'janu',
#   'Female',
#   'januilla1410@gamil.com',
#   'scrypt:32768:8:1$ru9o7Z1KxCi1jchP$d51572b5e10afc4667647f5e64f62844fbdf828924ea7cce91bcd49fed1a78e70f14795f5b2a51d7afbbb24dc35c72adee42efe3d9ac7f4e2214fc28a6dfcaa8',
#   '2026-03-31 12:08:56.736498')]

# %%
reg = []
for i in x:
    reg.append(i[3])

# %%
reg
# Out:
# ['PAUL@GMAIL.COM',
#  'jacob@gmail.com',
#  'illajahnavi14@gmail.com',
#  'januilla1410@gamil.com']

# %%
cur.execute("select * from verification")
x = cur.fetchall()
x
# Out:
# [(1, 2, 6057, 1038464.56, '2025-03-04 15:20:30', 'VERIFIED'),
#  (2, 3, 6058, 1038474.57, '2025-03-03 16:21:30', 'VERIFIED'),
#  (3, 4, 1453, 1774935877.7569957, '2026-03-31 11:10:08.436211', 'VERIFIED'),
#  (4, 5, 4116, 1774939378.498677, '2026-03-31 12:08:56.747955', 'VERIFIED')]

# %%
cur.execute("INSERT INTO VERIFICATION VALUES(5,6,6059,1038466.56,'2024-03-04 15:29:30','VERIFIED')")
conn.commit()

# %%
cur.execute("select * from EXPENSEPROFILE")
cur.fetchall()
# Out:
# []

# %%
cur.execute('''select created_at, groceries+travel+medfit+LeP+monthly_rent+m_bills+fashion+entertainment+education+emsaving+
            MISCELLANEOUS from expenseprofile
            where user_id = 
            (select user_id from user where email = 'januilla1410@gmail.com')
            order by created_at asc''')
cur.fetchall()
# Out:
# []

# %%
cur.execute("INSERT INTO EXPENSEPROFILE VALUES()")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cur.execute("INSERT INTO EXPENSEPROFILE VALUES()")
#
# OperationalError: near ")": syntax error

# %%
cur.execute("select user_id from user where email = 'januilla1410@gmail.com'")
cur.fetchall()
# Out:
# []

# %%
conn = sqlite3.connect('fintrackai.db')
cur = conn.cursor()
cur.execute("SELECT EMAIL,PASSWORD_HASH FROM USER")
x = cur.fetchall()
x
# Out:
# [('PAUL@GMAIL.COM', 'JHVCUYWFWEFSADT7F875JHV3296'),
#  ('jacob@gmail.com',
#   'scrypt:32768:8:1$kClqICHE704qLF3Y$c2b92e0ece13e421abb68088a4eb57502d2dd87f88a8a3927a5c204d0948bedfcd5da666a0f8dcfaffe9577ca4a994c838e297196832d7f4c21e88baa8b42f30'),
#  ('illajahnavi14@gmail.com',
#   'scrypt:32768:8:1$iTjjdNBLexnjH6K1$87cf3d2b7304ca7c38575bbbd372e164e7193a48349f34862665e007bf96c6748ebe095a42808e33de3a20134e1f8acb27ed9090de4dd08f3f50e950b64518cd'),
#  ('januilla1410@gamil.com',
#   'scrypt:32768:8:1$ru9o7Z1KxCi1jchP$d51572b5e10afc4667647f5e64f62844fbdf828924ea7cce91bcd49fed1a78e70f14795f5b2a51d7afbbb24dc35c72adee42efe3d9ac7f4e2214fc28a6dfcaa8')]

# %%
"ram@gmail.com" in dict(x)
# Out:
# False

# %%
cur.execute("SELECT 'Hello',EMAIL,PASSWORD_HASH FROM USER")
x = cur.fetchall()
x
# Out:
# [('Hello', 'PAUL@GMAIL.COM', 'JHVCUYWFWEFSADT7F875JHV3296'),
#  ('Hello',
#   'jacob@gmail.com',
#   'scrypt:32768:8:1$kClqICHE704qLF3Y$c2b92e0ece13e421abb68088a4eb57502d2dd87f88a8a3927a5c204d0948bedfcd5da666a0f8dcfaffe9577ca4a994c838e297196832d7f4c21e88baa8b42f30'),
#  ('Hello',
#   'illajahnavi14@gmail.com',
#   'scrypt:32768:8:1$iTjjdNBLexnjH6K1$87cf3d2b7304ca7c38575bbbd372e164e7193a48349f34862665e007bf96c6748ebe095a42808e33de3a20134e1f8acb27ed9090de4dd08f3f50e950b64518cd'),
#  ('Hello',
#   'januilla1410@gamil.com',
#   'scrypt:32768:8:1$ru9o7Z1KxCi1jchP$d51572b5e10afc4667647f5e64f62844fbdf828924ea7cce91bcd49fed1a78e70f14795f5b2a51d7afbbb24dc35c72adee42efe3d9ac7f4e2214fc28a6dfcaa8')]

# %%
profile_id = cur.execute("SELECT * FROM INCOMEPROFILE")
x = cur.fetchall()
x
# Out:
# [(1,
#   5,
#   'OTHERS',
#   70000.0,
#   'OTHERS',
#   0.0,
#   5,
#   '2026-04-01 14:56:50.267648',
#   '2026-04-01 14:56:50.267648')]

# %%
import numpy as np

# %%
cur.execute('''INSERT INTO GOALS (
    GOALID,
    USER_ID,
    GOAL_NAME,
    START_DATE,
    END_DATE,
    GOAL_AMOUNT,
    MONTHLY_SAVING_T,
    GOAL_STATUS,
    CREATED_AT,
    UPDATED_AT
)
VALUES (
    3,
    6,
    'Vacation Trip',
    '2025-02-01',
    '2025-07-31',
    90000,
    15000,
    'ACTIVE',
    DATETIME('now'),
    DATETIME('now')
)''')

conn.commit()

# %%
cur.execute('''INSERT INTO GOAL_HISTORY (
    HISTORY_ID,
    GOALID,
    CREATED_AT,
    SAVE_MONTH
)
VALUES
(4, 2, '2025-02-28', 14000),
(5, 2, '2025-03-31', 16000),
(6, 2, '2025-04-30', 15000)''')

conn.commit()

# %%
cur.execute("""
INSERT INTO EXPENSEPROFILE (
    EXPENSE_ID, USER_ID, GROCERIES, TRAVEL, MEDFIT, LEP,
    MONTHLY_RENT, M_BILLS, FASHION, ENTERTAINMENT,
    EDUCATION, EMSAVING, MISCELLANEOUS, CREATED_AT
) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
""", (
    2, 6, 3000.0, 1500.0, 800.0, 500.0,
    10000.0, 2000.0, 1200.0, 700.0,
    2500.0, 3000.0, 900.0, '2025-03-04 15:20:30'
))
conn.commit()

# %%
conn.commit()

# %%
cur.execute("select * from expenseprofile")
cur.fetchall()
# Out:
# [(1,
#   101,
#   3000.0,
#   1500.0,
#   800.0,
#   500.0,
#   10000.0,
#   2000.0,
#   1200.0,
#   700.0,
#   2500.0,
#   3000.0,
#   900.0,
#   '2025-03-04 15:20:30')]

# %%
def goal_tracker():
    conn = sqlite3.connect("fintrackai.db")
    cur = conn.cursor()
    cur.execute('''
    SELECT 
        GOAL_AMOUNT,
        SAVE_MONTH,
        CAST(((JULIANDAY(END_DATE) - JULIANDAY(START_DATE)) / 30.0) + 0.999 AS INT)
    FROM GOALS 
    JOIN GOAL_HISTORY USING(GOALID) 
    WHERE GOALS.USER_ID = (
        SELECT user_id FROM user WHERE email = "januilla1410@gmail.com"
    )
    AND GOALID = (
        SELECT MAX(GOALID) 
        FROM USER 
        JOIN GOALS USING(USER_ID)
        WHERE email = "januilla1410@gmail.com"
    )
''')
    x = cur.fetchall()
    print(x)
    if len(x)==0:
        return 1
    GA = x[0][0]
    sm = 0
    fixedmn = x[0][-1]
    targetedmn =[] 
    for i  in range(len(x)):
        mntarget = (GA-sm)/(fixedmn-i)
        sm = sm+x[i][1]
        targetedmn.append(mntarget)
    return targetedmn

# %%
goal_tracker()
# Out:
# []
# 1

# %%
import numpy as np

# %%
email = "illajahnavi1419@gmail.com"

cur.execute("DELETE FROM USER WHERE EMAIL = ?", (email,))
conn.commit()
